# %%
#CLEANUP THE TRADE DATA

import pandas as pd
import numpy as np

trade_data = pd.read_csv('all_trades_combined.csv', delimiter=';').fillna(0)


trade_data_pearls = pd.DataFrame(columns=trade_data.columns)
trade_data_bananas = pd.DataFrame(columns=trade_data.columns)
trade_data_coconuts = pd.DataFrame(columns=trade_data.columns)
trade_data_pina_coladas = pd.DataFrame(columns=trade_data.columns)
trade_data_diving_gear = pd.DataFrame(columns=trade_data.columns)
trade_data_berries = pd.DataFrame(columns=trade_data.columns)
trade_data_ukuleles = pd.DataFrame(columns=trade_data.columns)
trade_data_baguettes = pd.DataFrame(columns=trade_data.columns)
trade_data_dip = pd.DataFrame(columns=trade_data.columns)
trade_data_basket = pd.DataFrame(columns=trade_data.columns)





for idx, row in trade_data.iterrows():              # This is taking forever lmao, thank god you only have to run this once per day
    if row['symbol'] == 'PEARLS':
        trade_data_pearls.loc[idx] = row
    elif row['symbol'] == 'BANANAS':
        trade_data_bananas.loc[idx] = row
    elif row['symbol'] == 'COCONUTS':
        trade_data_coconuts.loc[idx] = row
    elif row['symbol'] == 'PINA_COLADAS':
        trade_data_pina_coladas.loc[idx] = row
    elif row['symbol'] == 'DIVING_GEAR':
        trade_data_diving_gear.loc[idx] = row
    elif row['symbol'] == 'BERRIES':
        trade_data_berries.loc[idx] = row
    elif row['symbol'] == 'UKULELE':
        trade_data_ukuleles.loc[idx] = row
    elif row['symbol'] == 'BAGUETTE':
        trade_data_baguettes.loc[idx] = row
    elif row['symbol'] == 'DIP':
        trade_data_dip.loc[idx] = row
    elif row['symbol'] == 'PICNIC_BASKET':
        trade_data_basket.loc[idx] = row




trade_data_pearls = trade_data_pearls.reset_index()
trade_data_bananas = trade_data_bananas.reset_index()
trade_data_coconuts = trade_data_coconuts.reset_index()
trade_data_pina_coladas = trade_data_pina_coladas.reset_index()
trade_data_diving_gear = trade_data_diving_gear.reset_index()
trade_data_berries = trade_data_berries.reset_index()
trade_data_ukuleles = trade_data_ukuleles.reset_index()
trade_data_baguettes = trade_data_baguettes.reset_index()
trade_data_dip = trade_data_dip.reset_index()
trade_data_basket = trade_data_basket.reset_index()


trade_data_pearls = trade_data_pearls.drop(['symbol', 'index'], axis=1)
trade_data_bananas = trade_data_bananas.drop(['symbol', 'index'], axis=1)
trade_data_coconuts = trade_data_coconuts.drop(['symbol', 'index'], axis=1)
trade_data_pina_coladas = trade_data_pina_coladas.drop(['symbol', 'index'], axis=1)
trade_data_diving_gear = trade_data_diving_gear.drop(['symbol', 'index'], axis=1)
trade_data_berries =trade_data_berries.drop(['symbol', 'index'], axis=1)
trade_data_ukuleles =trade_data_ukuleles.drop(['symbol', 'index'], axis=1)
trade_data_baguettes =trade_data_baguettes.drop(['symbol', 'index'], axis=1)
trade_data_dip =trade_data_dip.drop(['symbol', 'index'], axis=1)
trade_data_basket =trade_data_basket.drop(['symbol', 'index'], axis=1)


trade_data_pearls['timestamp'] = ((trade_data_pearls['timestamp'] / 100) + 1) + ((trade_data_pearls['day'] + 2) * 10000)

trade_data_bananas['timestamp'] = ((trade_data_bananas['timestamp'] / 100) + 1) + ((trade_data_bananas['day'] + 2) * 10000)

trade_data_coconuts['timestamp'] = ((trade_data_coconuts['timestamp'] / 100) + 1) + ((trade_data_coconuts['day'] + 2) * 10000)

trade_data_pina_coladas['timestamp'] = ((trade_data_pina_coladas['timestamp'] / 100) + 1) + ((trade_data_pina_coladas['day'] + 2) * 10000)

trade_data_diving_gear['timestamp'] = ((trade_data_diving_gear['timestamp'] / 100) + 1) + ((trade_data_diving_gear['day'] + 2) * 10000)

trade_data_berries['timestamp'] = ((trade_data_berries['timestamp'] / 100) + 1) + ((trade_data_berries['day'] + 2) * 10000)

trade_data_ukuleles['timestamp'] = ((trade_data_ukuleles['timestamp'] / 100) + 1) + ((trade_data_ukuleles['day'] + 2) * 10000)

trade_data_baguettes['timestamp'] = ((trade_data_baguettes['timestamp'] / 100) + 1) + ((trade_data_baguettes['day'] + 2) * 10000)

trade_data_dip['timestamp'] = ((trade_data_dip['timestamp'] / 100) + 1) + ((trade_data_dip['day'] + 2) * 10000)

trade_data_basket['timestamp'] = ((trade_data_basket['timestamp'] / 100) + 1) + ((trade_data_basket['day'] + 2) * 10000)


#SAFE DATA AS CSV

trade_data_pearls.to_csv('pearls_trade_data_all.csv', sep=';', header=trade_data_pearls.columns, index=False)
trade_data_bananas.to_csv('bananas_trade_data_all.csv', sep=';', header=trade_data_bananas.columns, index=False)
trade_data_coconuts.to_csv('coconuts_trade_data_all.csv', sep=';', header=trade_data_coconuts.columns, index=False)
trade_data_pina_coladas.to_csv('pina_coladas_trade_data_all.csv', sep=';', header=trade_data_pina_coladas.columns, index=False)
trade_data_diving_gear.to_csv('diving_gear_trade_data_all.csv', sep=';', header=trade_data_diving_gear.columns, index=False)
trade_data_berries.to_csv('berries_trade_data_all.csv', sep=';', header=trade_data_berries.columns, index=False)
trade_data_ukuleles.to_csv('ukuleles_trade_data_all.csv', sep=';', header=trade_data_ukuleles.columns, index=False)
trade_data_baguettes.to_csv('baguette_trade_data_all.csv', sep=';', header=trade_data_baguettes.columns, index=False)
trade_data_dip.to_csv('dip_trade_data_all.csv', sep=';', header=trade_data_dip.columns, index=False)
trade_data_basket.to_csv('basket_trade_data_all.csv', sep=';', header=trade_data_basket.columns, index=False)

# %%
#CLEANUP THE PRICE DATA
orderbook_data = pd.read_csv('all_prices_combined.csv', delimiter=';').fillna(0)

orderbook_data_pearls = pd.DataFrame(columns=orderbook_data.columns)
orderbook_data_bananas = pd.DataFrame(columns=orderbook_data.columns)
orderbook_data_coconuts = pd.DataFrame(columns=orderbook_data.columns)
orderbook_data_pina_coladas = pd.DataFrame(columns=orderbook_data.columns)
orderbook_data_diving_gear = pd.DataFrame(columns=orderbook_data.columns)
orderbook_data_berries = pd.DataFrame(columns=orderbook_data.columns)
orderbook_data_dolphin_sightings = pd.DataFrame(columns=orderbook_data.columns)
orderbook_data_ukuleles = pd.DataFrame(columns=orderbook_data.columns)
orderbook_data_baguette = pd.DataFrame(columns=orderbook_data.columns)
orderbook_data_dip = pd.DataFrame(columns=orderbook_data.columns)
orderbook_data_basket = pd.DataFrame(columns=orderbook_data.columns)

for idx, row in orderbook_data.iterrows():
    if row['product'] == 'PEARLS':
        orderbook_data_pearls.loc[idx] = row
    elif row['product'] == 'BANANAS':
        orderbook_data_bananas.loc[idx] = row
    elif row['product'] == 'COCONUTS':
        orderbook_data_coconuts.loc[idx] = row
    elif row['product'] == 'PINA_COLADAS':
        orderbook_data_pina_coladas.loc[idx] = row
    elif row['product'] == 'DIVING_GEAR':
        orderbook_data_diving_gear.loc[idx] = row
    elif row['product'] == 'BERRIES':
        orderbook_data_berries.loc[idx] = row
    elif row['product'] == 'DOLPHIN_SIGHTINGS':
        orderbook_data_dolphin_sightings.loc[idx] = row
    elif row['product'] == 'UKULELE':
        orderbook_data_ukuleles.loc[idx] = row
    elif row['product'] == 'BAGUETTE':
        orderbook_data_baguette.loc[idx] = row
    elif row['product'] == 'DIP':
        orderbook_data_dip.loc[idx] = row
    elif row['product'] == 'PICNIC_BASKET':
        orderbook_data_basket.loc[idx] = row

orderbook_data_pearls = orderbook_data_pearls.reset_index()
orderbook_data_bananas = orderbook_data_bananas.reset_index()
orderbook_data_coconuts = orderbook_data_coconuts.reset_index()
orderbook_data_pina_coladas = orderbook_data_pina_coladas.reset_index()
orderbook_data_diving_gear = orderbook_data_diving_gear.reset_index()
orderbook_data_berries = orderbook_data_berries.reset_index()
orderbook_data_dolphin_sightings = orderbook_data_dolphin_sightings.reset_index()
orderbook_data_ukuleles = orderbook_data_ukuleles.reset_index()
orderbook_data_baguette = orderbook_data_baguette.reset_index()
orderbook_data_dip = orderbook_data_dip.reset_index()
orderbook_data_basket = orderbook_data_basket.reset_index()

orderbook_data_pearls = orderbook_data_pearls.drop(['product', 'index'], axis=1)
orderbook_data_bananas = orderbook_data_bananas.drop(['product', 'index'], axis=1)
orderbook_data_coconuts = orderbook_data_coconuts.drop(['product', 'index'], axis=1)
orderbook_data_pina_coladas = orderbook_data_pina_coladas.drop(['product', 'index'], axis=1)
orderbook_data_diving_gear = orderbook_data_diving_gear.drop(['product', 'index'], axis=1)
orderbook_data_berries = orderbook_data_berries.drop(['product', 'index'], axis=1)
orderbook_data_dolphin_sightings = orderbook_data_dolphin_sightings.drop(['product', 'index'], axis=1)
orderbook_data_ukuleles = orderbook_data_ukuleles.drop(['product', 'index'], axis=1)
orderbook_data_baguette = orderbook_data_baguette.drop(['product', 'index'], axis=1)
orderbook_data_dip = orderbook_data_dip.drop(['product', 'index'], axis=1)
orderbook_data_basket = orderbook_data_basket.drop(['product', 'index'], axis=1)

orderbook_data_pearls['timestamp'] = ((orderbook_data_pearls['timestamp'] / 100) + 1) + ((orderbook_data_pearls['day'] + 2) * 10000)
orderbook_data_bananas['timestamp'] = ((orderbook_data_bananas['timestamp'] / 100) + 1) + ((orderbook_data_bananas['day'] + 2) * 10000)
orderbook_data_coconuts['timestamp'] = ((orderbook_data_coconuts['timestamp'] / 100) + 1) + ((orderbook_data_coconuts['day'] + 2) * 10000)
orderbook_data_pina_coladas['timestamp'] = ((orderbook_data_pina_coladas['timestamp'] / 100) + 1) + ((orderbook_data_pina_coladas['day'] + 2) * 10000)
orderbook_data_diving_gear['timestamp'] = ((orderbook_data_diving_gear['timestamp'] / 100) + 1) + ((orderbook_data_diving_gear['day'] + 2) * 10000)
orderbook_data_berries['timestamp'] = ((orderbook_data_berries['timestamp'] / 100) + 1) + ((orderbook_data_berries['day'] + 2) * 10000)
orderbook_data_dolphin_sightings['timestamp'] = ((orderbook_data_dolphin_sightings['timestamp'] / 100) + 1) + ((orderbook_data_dolphin_sightings['day'] + 2) * 10000)
orderbook_data_ukuleles['timestamp'] = ((orderbook_data_ukuleles['timestamp'] / 100) + 1) + ((orderbook_data_ukuleles['day'] + 2) * 10000)
orderbook_data_baguette['timestamp'] = ((orderbook_data_baguette['timestamp'] / 100) + 1) + ((orderbook_data_baguette['day'] + 2) * 10000)
orderbook_data_dip['timestamp'] = ((orderbook_data_dip['timestamp'] / 100) + 1) + ((orderbook_data_dip['day'] + 2) * 10000)
orderbook_data_basket['timestamp'] = ((orderbook_data_basket['timestamp'] / 100) + 1) + ((orderbook_data_basket['day'] + 2) * 10000)

orderbook_data_pearls.to_csv('pearls_orderbook_data_all.csv', sep=';', header=orderbook_data_pearls.columns, index=False)
orderbook_data_bananas.to_csv('bananas_orderbook_data_all.csv', sep=';', header=orderbook_data_bananas.columns, index=False)
orderbook_data_coconuts.to_csv('coconuts_orderbook_data_all.csv', sep=';', header=orderbook_data_coconuts.columns, index=False)
orderbook_data_pina_coladas.to_csv('pina_coladas_orderbook_data_all.csv', sep=';', header=orderbook_data_pina_coladas.columns, index=False)
orderbook_data_diving_gear.to_csv('diving_gear_orderbook_data_all.csv', sep=';', header=orderbook_data_diving_gear.columns, index=False)
orderbook_data_berries.to_csv('berries_orderbook_data_all.csv', sep=';', header=orderbook_data_berries.columns, index=False)
orderbook_data_dolphin_sightings.to_csv('dolphin_sightings_orderbook_data_all.csv', sep=';', header=orderbook_data_dolphin_sightings.columns, index=False)
orderbook_data_ukuleles.to_csv('ukuleles_orderbook_data_all.csv', sep=';', header=orderbook_data_ukuleles.columns, index=False)
orderbook_data_baguette.to_csv('baguette_orderbook_data_all.csv', sep=';', header=orderbook_data_baguette.columns, index=False)
orderbook_data_dip.to_csv('dip_orderbook_data_all.csv', sep=';', header=orderbook_data_dip.columns, index=False)
orderbook_data_basket.to_csv('basket_orderbook_data_all.csv', sep=';', header=orderbook_data_basket.columns, index=False)

# %%
#BANANA PREP
import pandas as pd

price_data = pd.read_csv('bananas_orderbook_data_all.csv', delimiter=';').fillna(0)
trade_data = pd.read_csv('bananas_trade_data_all.csv', delimiter=';').fillna(0)

price_data['smart_price'] = (((price_data['bid_price_1']*price_data['bid_volume_1'] + price_data['bid_price_2']*price_data['bid_volume_2'] + price_data['bid_price_3']*price_data['bid_volume_3']) / (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) * (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']) + \
                            ((price_data['ask_price_1']*price_data['ask_volume_1'] + price_data['ask_price_2']*price_data['ask_volume_2'] + price_data['ask_price_3']*price_data['ask_volume_3']) / (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3'])) * (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) / \
                                (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']+price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])
price_data = price_data.drop(['bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3', 'profit_and_loss', 'day', 'timestamp', 'mid_price'], axis=1)

traders = pd.DataFrame(columns=['timestamp', 'name', 'buys', 'sells', 'price'])

for idx, row in trade_data.iterrows():  
    
    data = pd.DataFrame(data={'timestamp': [row['timestamp'], row['timestamp']], 'name' : [row['buyer'], row['seller']], 'buys' : [row['quantity'], 0], 'sells' : [0, -row['quantity']], 'price': [row['price'], row['price']]}, columns=['timestamp', 'name', 'buys', 'sells', 'price'])
    traders = pd.concat([traders, data], axis=0)

traders = traders.groupby(['timestamp', 'name', 'price'], as_index=False).agg({'buys': 'sum', 'sells': 'sum'})

# %%
#BANANA ANALYSIS
import matplotlib.pyplot as plt
import plotly.graph_objects as go


fig = go.Figure()

fig.add_trace(go.Scatter(x=price_data.index, y=price_data['smart_price'],
                    mode='lines',
                    name='price',
                    line=dict(color = 'rgb(128, 128, 128)')))

trader_observed = 'Olivia'


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['price'],
                    mode='markers', name='buys', marker=dict(color = 'rgb(0, 204, 0)', size = 8, symbol = 'triangle-up')))


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['price'],
                    mode='markers', name='sells', marker=dict(color = 'rgb(255, 0, 0)', size = 8, symbol = 'triangle-down')))


fig.show()

# %%
#PEARLS PREP
import pandas as pd

price_data = pd.read_csv('pearls_orderbook_data_all.csv', delimiter=';').fillna(0)
trade_data = pd.read_csv('pearls_trade_data_all.csv', delimiter=';').fillna(0)

price_data['smart_price'] = (((price_data['bid_price_1']*price_data['bid_volume_1'] + price_data['bid_price_2']*price_data['bid_volume_2'] + price_data['bid_price_3']*price_data['bid_volume_3']) / (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) * (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']) + \
                            ((price_data['ask_price_1']*price_data['ask_volume_1'] + price_data['ask_price_2']*price_data['ask_volume_2'] + price_data['ask_price_3']*price_data['ask_volume_3']) / (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3'])) * (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) / \
                                (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']+price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])
price_data = price_data.drop(['bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3', 'profit_and_loss', 'day', 'timestamp', 'mid_price'], axis=1)

traders = pd.DataFrame(columns=['timestamp', 'name', 'buys', 'sells', 'price'])

for idx, row in trade_data.iterrows():  
    
    data = pd.DataFrame(data={'timestamp': [row['timestamp'], row['timestamp']], 'name' : [row['buyer'], row['seller']], 'buys' : [row['quantity'], 0], 'sells' : [0, -row['quantity']], 'price': [row['price'], row['price']]}, columns=['timestamp', 'name', 'buys', 'sells', 'price'])
    traders = pd.concat([traders, data], axis=0)

traders = traders.groupby(['timestamp', 'name', 'price'], as_index=False).agg({'buys': 'sum', 'sells': 'sum'})

# %%
#PEARLS ANALYSIS
import matplotlib.pyplot as plt
import plotly.graph_objects as go


fig = go.Figure()

fig.add_trace(go.Scatter(x=price_data.index, y=price_data['smart_price'],
                    mode='lines',
                    name='price',
                    line=dict(color = 'rgb(128, 128, 128)')))

trader_observed = 'Pablo'


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['price'],
                    mode='markers', name='buys', marker=dict(color = 'rgb(0, 204, 0)', size = 8, symbol = 'triangle-up')))


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['price'],
                    mode='markers', name='sells', marker=dict(color = 'rgb(255, 0, 0)', size = 8, symbol = 'triangle-down')))


fig.show()

# %%
#PINA_COLADAS PREP
import pandas as pd

price_data = pd.read_csv('pina_coladas_orderbook_data_all.csv', delimiter=';').fillna(0)
trade_data = pd.read_csv('pina_coladas_trade_data_all.csv', delimiter=';').fillna(0)

price_data['smart_price'] = (((price_data['bid_price_1']*price_data['bid_volume_1'] + price_data['bid_price_2']*price_data['bid_volume_2'] + price_data['bid_price_3']*price_data['bid_volume_3']) / (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) * (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']) + \
                            ((price_data['ask_price_1']*price_data['ask_volume_1'] + price_data['ask_price_2']*price_data['ask_volume_2'] + price_data['ask_price_3']*price_data['ask_volume_3']) / (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3'])) * (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) / \
                                (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']+price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])
price_data = price_data.drop(['bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3', 'profit_and_loss', 'day', 'mid_price'], axis=1)

traders = pd.DataFrame(columns=['timestamp', 'name', 'buys', 'sells', 'price'])

for idx, row in trade_data.iterrows():  
    
    data = pd.DataFrame(data={'timestamp': [row['timestamp'], row['timestamp']], 'name' : [row['buyer'], row['seller']], 'buys' : [row['quantity'], 0], 'sells' : [0, -row['quantity']], 'price': [row['price'], row['price']]}, columns=['timestamp', 'name', 'buys', 'sells', 'price'])
    traders = pd.concat([traders, data], axis=0)

traders = traders.groupby(['timestamp', 'name', 'price'], as_index=False).agg({'buys': 'sum', 'sells': 'sum'})

# %%
#PINA_COLADAS ANALYSIS

import matplotlib.pyplot as plt
import plotly.graph_objects as go


fig = go.Figure()

fig.add_trace(go.Scatter(x=price_data['timestamp'], y=price_data['smart_price'],
                    mode='lines',
                    name='price',
                    line=dict(color = 'rgb(128, 128, 128)')))

trader_observed = 'Pablo'


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['price'],
                    mode='markers', name='buys', marker=dict(color = 'rgb(0, 204, 0)', size = 8, symbol = 'triangle-up')))


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['price'],
                    mode='markers', name='sells', marker=dict(color = 'rgb(255, 0, 0)', size = 8, symbol = 'triangle-down')))


fig.show()

# %%
#COCONUT PREP
import pandas as pd

price_data = pd.read_csv('coconuts_orderbook_data_all.csv', delimiter=';').fillna(0)
trade_data = pd.read_csv('coconuts_trade_data_all.csv', delimiter=';').fillna(0)

price_data['smart_price'] = (((price_data['bid_price_1']*price_data['bid_volume_1'] + price_data['bid_price_2']*price_data['bid_volume_2'] + price_data['bid_price_3']*price_data['bid_volume_3']) / (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) * (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']) + \
                            ((price_data['ask_price_1']*price_data['ask_volume_1'] + price_data['ask_price_2']*price_data['ask_volume_2'] + price_data['ask_price_3']*price_data['ask_volume_3']) / (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3'])) * (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) / \
                                (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']+price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])
price_data = price_data.drop(['bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3', 'profit_and_loss', 'day', 'mid_price'], axis=1)

traders = pd.DataFrame(columns=['timestamp', 'name', 'buys', 'sells', 'price'])

for idx, row in trade_data.iterrows():  
    
    data = pd.DataFrame(data={'timestamp': [row['timestamp'], row['timestamp']], 'name' : [row['buyer'], row['seller']], 'buys' : [row['quantity'], 0], 'sells' : [0, -row['quantity']], 'price': [row['price'], row['price']]}, columns=['timestamp', 'name', 'buys', 'sells', 'price'])
    traders = pd.concat([traders, data], axis=0)

traders = traders.groupby(['timestamp', 'name', 'price'], as_index=False).agg({'buys': 'sum', 'sells': 'sum'})

# %%
#COCONUT ANALYSIS
import matplotlib.pyplot as plt
import plotly.graph_objects as go


fig = go.Figure()

fig.add_trace(go.Scatter(x=price_data['timestamp'], y=price_data['smart_price'],
                    mode='lines',
                    name='price',
                    line=dict(color = 'rgb(128, 128, 128)')))

trader_observed = 'Charlie'


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['price'],
                    mode='markers', name='buys', marker=dict(color = 'rgb(0, 204, 0)', size = 8, symbol = 'triangle-up')))


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['price'],
                    mode='markers', name='sells', marker=dict(color = 'rgb(255, 0, 0)', size = 8, symbol = 'triangle-down')))


fig.show()

# %%
#DIVING_GEAR PREP
import pandas as pd

price_data = pd.read_csv('diving_gear_orderbook_data_all.csv', delimiter=';').fillna(0)
trade_data = pd.read_csv('diving_gear_trade_data_all.csv', delimiter=';').fillna(0)

price_data['smart_price'] = (((price_data['bid_price_1']*price_data['bid_volume_1'] + price_data['bid_price_2']*price_data['bid_volume_2'] + price_data['bid_price_3']*price_data['bid_volume_3']) / (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) * (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']) + \
                            ((price_data['ask_price_1']*price_data['ask_volume_1'] + price_data['ask_price_2']*price_data['ask_volume_2'] + price_data['ask_price_3']*price_data['ask_volume_3']) / (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3'])) * (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) / \
                                (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']+price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])
price_data = price_data.drop(['bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3', 'profit_and_loss', 'day', 'mid_price'], axis=1)

traders = pd.DataFrame(columns=['timestamp', 'name', 'buys', 'sells', 'price'])

for idx, row in trade_data.iterrows():  
    
    data = pd.DataFrame(data={'timestamp': [row['timestamp'], row['timestamp']], 'name' : [row['buyer'], row['seller']], 'buys' : [row['quantity'], 0], 'sells' : [0, -row['quantity']], 'price': [row['price'], row['price']]}, columns=['timestamp', 'name', 'buys', 'sells', 'price'])
    traders = pd.concat([traders, data], axis=0)

traders = traders.groupby(['timestamp', 'name', 'price'], as_index=False).agg({'buys': 'sum', 'sells': 'sum'})

# %%
#DIVING_GEAR ANALYSIS
import matplotlib.pyplot as plt
import plotly.graph_objects as go


fig = go.Figure()

fig.add_trace(go.Scatter(x=price_data['timestamp'], y=price_data['smart_price'],
                    mode='lines',
                    name='price',
                    line=dict(color = 'rgb(128, 128, 128)')))

trader_observed = 'Camilla'


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['price'],
                    mode='markers', name='buys', marker=dict(color = 'rgb(0, 204, 0)', size = 8, symbol = 'triangle-up')))


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['price'],
                    mode='markers', name='sells', marker=dict(color = 'rgb(255, 0, 0)', size = 8, symbol = 'triangle-down')))


fig.show()

# %%
#BERRIES PREP
import pandas as pd

price_data = pd.read_csv('berries_orderbook_data_all.csv', delimiter=';').fillna(0)
trade_data = pd.read_csv('berries_trade_data_all.csv', delimiter=';').fillna(0)

price_data['smart_price'] = (((price_data['bid_price_1']*price_data['bid_volume_1'] + price_data['bid_price_2']*price_data['bid_volume_2'] + price_data['bid_price_3']*price_data['bid_volume_3']) / (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) * (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']) + \
                            ((price_data['ask_price_1']*price_data['ask_volume_1'] + price_data['ask_price_2']*price_data['ask_volume_2'] + price_data['ask_price_3']*price_data['ask_volume_3']) / (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3'])) * (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) / \
                                (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']+price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])
price_data = price_data.drop(['bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3', 'profit_and_loss', 'day', 'mid_price'], axis=1)

traders = pd.DataFrame(columns=['timestamp', 'name', 'buys', 'sells', 'price'])

for idx, row in trade_data.iterrows():  
    
    data = pd.DataFrame(data={'timestamp': [row['timestamp'], row['timestamp']], 'name' : [row['buyer'], row['seller']], 'buys' : [row['quantity'], 0], 'sells' : [0, -row['quantity']], 'price': [row['price'], row['price']]}, columns=['timestamp', 'name', 'buys', 'sells', 'price'])
    traders = pd.concat([traders, data], axis=0)

traders = traders.groupby(['timestamp', 'name', 'price'], as_index=False).agg({'buys': 'sum', 'sells': 'sum'})

# %%
#BERRIES ANALYSIS
import matplotlib.pyplot as plt
import plotly.graph_objects as go


fig = go.Figure()

fig.add_trace(go.Scatter(x=price_data['timestamp'], y=price_data['smart_price'],
                    mode='lines',
                    name='price',
                    line=dict(color = 'rgb(128, 128, 128)')))

trader_observed = 'Charlie'


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['price'],
                    mode='markers', name='buys', marker=dict(color = 'rgb(0, 204, 0)', size = 8, symbol = 'triangle-up')))


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['price'],
                    mode='markers', name='sells', marker=dict(color = 'rgb(255, 0, 0)', size = 8, symbol = 'triangle-down')))


fig.show()

# %%
#UKULELES PREP
import pandas as pd

price_data = pd.read_csv('ukuleles_orderbook_data_all.csv', delimiter=';').fillna(0)
trade_data = pd.read_csv('ukuleles_trade_data_all.csv', delimiter=';').fillna(0)

price_data['smart_price'] = (((price_data['bid_price_1']*price_data['bid_volume_1'] + price_data['bid_price_2']*price_data['bid_volume_2'] + price_data['bid_price_3']*price_data['bid_volume_3']) / (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) * (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']) + \
                            ((price_data['ask_price_1']*price_data['ask_volume_1'] + price_data['ask_price_2']*price_data['ask_volume_2'] + price_data['ask_price_3']*price_data['ask_volume_3']) / (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3'])) * (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) / \
                                (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']+price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])
price_data = price_data.drop(['bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3', 'profit_and_loss', 'day', 'mid_price'], axis=1)

traders = pd.DataFrame(columns=['timestamp', 'name', 'buys', 'sells', 'price'])

for idx, row in trade_data.iterrows():  
    
    data = pd.DataFrame(data={'timestamp': [row['timestamp'], row['timestamp']], 'name' : [row['buyer'], row['seller']], 'buys' : [row['quantity'], 0], 'sells' : [0, -row['quantity']], 'price': [row['price'], row['price']]}, columns=['timestamp', 'name', 'buys', 'sells', 'price'])
    traders = pd.concat([traders, data], axis=0)

traders = traders.groupby(['timestamp', 'name', 'price'], as_index=False).agg({'buys': 'sum', 'sells': 'sum'})

# %%
#UKULELES ANALYSIS
import matplotlib.pyplot as plt
import plotly.graph_objects as go


fig = go.Figure()

fig.add_trace(go.Scatter(x=price_data['timestamp'], y=price_data['smart_price'],
                    mode='lines',
                    name='price',
                    line=dict(color = 'rgb(128, 128, 128)')))

trader_observed = 'Olivia'


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['price'],
                    mode='markers', name='buys', marker=dict(color = 'rgb(0, 204, 0)', size = 8, symbol = 'triangle-up')))


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['price'],
                    mode='markers', name='sells', marker=dict(color = 'rgb(255, 0, 0)', size = 8, symbol = 'triangle-down')))


fig.show()

# %%
#BAGUETTES PREP
import pandas as pd

price_data = pd.read_csv('baguette_orderbook_data_all.csv', delimiter=';').fillna(0)
trade_data = pd.read_csv('baguette_trade_data_all.csv', delimiter=';').fillna(0)

price_data['smart_price'] = (((price_data['bid_price_1']*price_data['bid_volume_1'] + price_data['bid_price_2']*price_data['bid_volume_2'] + price_data['bid_price_3']*price_data['bid_volume_3']) / (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) * (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']) + \
                            ((price_data['ask_price_1']*price_data['ask_volume_1'] + price_data['ask_price_2']*price_data['ask_volume_2'] + price_data['ask_price_3']*price_data['ask_volume_3']) / (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3'])) * (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) / \
                                (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']+price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])
price_data = price_data.drop(['bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3', 'profit_and_loss', 'day', 'mid_price'], axis=1)

traders = pd.DataFrame(columns=['timestamp', 'name', 'buys', 'sells', 'price'])

for idx, row in trade_data.iterrows():  
    
    data = pd.DataFrame(data={'timestamp': [row['timestamp'], row['timestamp']], 'name' : [row['buyer'], row['seller']], 'buys' : [row['quantity'], 0], 'sells' : [0, -row['quantity']], 'price': [row['price'], row['price']]}, columns=['timestamp', 'name', 'buys', 'sells', 'price'])
    traders = pd.concat([traders, data], axis=0)

traders = traders.groupby(['timestamp', 'name', 'price'], as_index=False).agg({'buys': 'sum', 'sells': 'sum'})

# %%
#BAGUETTES ANALYSIS
import matplotlib.pyplot as plt
import plotly.graph_objects as go


fig = go.Figure()

fig.add_trace(go.Scatter(x=price_data['timestamp'], y=price_data['smart_price'],
                    mode='lines',
                    name='price',
                    line=dict(color = 'rgb(128, 128, 128)')))

trader_observed = 'Camilla'


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['price'],
                    mode='markers', name='buys', marker=dict(color = 'rgb(0, 204, 0)', size = 8, symbol = 'triangle-up')))


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['price'],
                    mode='markers', name='sells', marker=dict(color = 'rgb(255, 0, 0)', size = 8, symbol = 'triangle-down')))


fig.show()

# %%
#DIP PREP
import pandas as pd

price_data = pd.read_csv('dip_orderbook_data_all.csv', delimiter=';').fillna(0)
trade_data = pd.read_csv('dip_trade_data_all.csv', delimiter=';').fillna(0)

price_data['smart_price'] = (((price_data['bid_price_1']*price_data['bid_volume_1'] + price_data['bid_price_2']*price_data['bid_volume_2'] + price_data['bid_price_3']*price_data['bid_volume_3']) / (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) * (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']) + \
                            ((price_data['ask_price_1']*price_data['ask_volume_1'] + price_data['ask_price_2']*price_data['ask_volume_2'] + price_data['ask_price_3']*price_data['ask_volume_3']) / (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3'])) * (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) / \
                                (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']+price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])
price_data = price_data.drop(['bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3', 'profit_and_loss', 'day', 'mid_price'], axis=1)

traders = pd.DataFrame(columns=['timestamp', 'name', 'buys', 'sells', 'price'])

for idx, row in trade_data.iterrows():  
    
    data = pd.DataFrame(data={'timestamp': [row['timestamp'], row['timestamp']], 'name' : [row['buyer'], row['seller']], 'buys' : [row['quantity'], 0], 'sells' : [0, -row['quantity']], 'price': [row['price'], row['price']]}, columns=['timestamp', 'name', 'buys', 'sells', 'price'])
    traders = pd.concat([traders, data], axis=0)

traders = traders.groupby(['timestamp', 'name', 'price'], as_index=False).agg({'buys': 'sum', 'sells': 'sum'})

# %%
#DIP ANALYSIS
import matplotlib.pyplot as plt
import plotly.graph_objects as go


fig = go.Figure()

fig.add_trace(go.Scatter(x=price_data['timestamp'], y=price_data['smart_price'],
                    mode='lines',
                    name='price',
                    line=dict(color = 'rgb(128, 128, 128)')))

trader_observed = 'Camilla'


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['price'],
                    mode='markers', name='buys', marker=dict(color = 'rgb(0, 204, 0)', size = 8, symbol = 'triangle-up')))


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['price'],
                    mode='markers', name='sells', marker=dict(color = 'rgb(255, 0, 0)', size = 8, symbol = 'triangle-down')))


fig.show()

# %%
#PICNIC BASKET PREP
import pandas as pd

price_data = pd.read_csv('basket_orderbook_data_all.csv', delimiter=';').fillna(0)
trade_data = pd.read_csv('basket_trade_data_all.csv', delimiter=';').fillna(0)

price_data['smart_price'] = (((price_data['bid_price_1']*price_data['bid_volume_1'] + price_data['bid_price_2']*price_data['bid_volume_2'] + price_data['bid_price_3']*price_data['bid_volume_3']) / (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) * (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']) + \
                            ((price_data['ask_price_1']*price_data['ask_volume_1'] + price_data['ask_price_2']*price_data['ask_volume_2'] + price_data['ask_price_3']*price_data['ask_volume_3']) / (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3'])) * (price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])) / \
                                (price_data['ask_volume_1']+price_data['ask_volume_2']+price_data['ask_volume_3']+price_data['bid_volume_1']+price_data['bid_volume_2']+price_data['bid_volume_3'])
price_data = price_data.drop(['bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3', 'profit_and_loss', 'day', 'mid_price'], axis=1)

traders = pd.DataFrame(columns=['timestamp', 'name', 'buys', 'sells', 'price'])

for idx, row in trade_data.iterrows():  
    
    data = pd.DataFrame(data={'timestamp': [row['timestamp'], row['timestamp']], 'name' : [row['buyer'], row['seller']], 'buys' : [row['quantity'], 0], 'sells' : [0, -row['quantity']], 'price': [row['price'], row['price']]}, columns=['timestamp', 'name', 'buys', 'sells', 'price'])
    traders = pd.concat([traders, data], axis=0)

traders = traders.groupby(['timestamp', 'name', 'price'], as_index=False).agg({'buys': 'sum', 'sells': 'sum'})

# %%
#BASKET ANALYSIS
import matplotlib.pyplot as plt
import plotly.graph_objects as go


fig = go.Figure()

fig.add_trace(go.Scatter(x=price_data['timestamp'], y=price_data['smart_price'],
                    mode='lines',
                    name='price',
                    line=dict(color = 'rgb(128, 128, 128)')))

trader_observed = 'Penelope'


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['buys'] != 0)]['price'],
                    mode='markers', name='buys', marker=dict(color = 'rgb(0, 204, 0)', size = 8, symbol = 'triangle-up')))


fig.add_trace(go.Scatter(x=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['timestamp'], y=traders.loc[(traders['name'] == trader_observed) & (traders['sells'] != 0)]['price'],
                    mode='markers', name='sells', marker=dict(color = 'rgb(255, 0, 0)', size = 8, symbol = 'triangle-down')))


fig.show()
