# %%
import numpy as np
import matplotlib.pyplot as plt

perc_invst = np.linspace(0, 100, 100)
perc_gain = 39


fee = 1.2 * 750000 * (perc_invst / 100)**2
investment = (750000 * (perc_invst / 100))
breakeven = fee + investment
perc_to_breakeven = breakeven/investment -1


def true_pnl(perc_invst, perc_gain):
    return ((750000 * (perc_invst / 100)) * ((perc_gain/100)+1)) - (( 1.2 * 750000 * (perc_invst / 100)**2) +  (750000 * (perc_invst / 100)))

pnl = true_pnl(perc_invst, perc_gain)



fig = plt.figure()
plt.plot(pnl)
plt.ylim(0)

print(max(pnl))
print(pnl)
#plt.plot(fee)
#plt.plot(investment)
#plt.plot(breakeven)
# Out:
# [ 0.00000000e+00  2.86271809e+03  5.54178145e+03  8.03719008e+03
#   1.03489440e+04  1.24770432e+04  1.44214876e+04  1.61822773e+04
#   1.77594123e+04  1.91528926e+04  2.03627181e+04  2.13888889e+04
#   2.22314050e+04  2.28902663e+04  2.33654729e+04  2.36570248e+04
#   2.37649219e+04  2.36891644e+04  2.34297521e+04  2.29866850e+04
#   2.23599633e+04  2.15495868e+04  2.05555556e+04  1.93778696e+04
#   1.80165289e+04  1.64715335e+04  1.47428834e+04  1.28305785e+04
#   1.07346189e+04  8.45500459e+03  5.99173554e+03  3.34481175e+03
#   5.14233242e+02 -2.50000000e+03 -5.69788797e+03 -9.07943067e+03
#  -1.26446281e+04 -1.63934803e+04 -2.03259871e+04 -2.44421488e+04
#  -2.87419651e+04 -3.32254362e+04 -3.78925620e+04 -4.27433425e+04
#  -4.77777778e+04 -5.29958678e+04 -5.83976125e+04 -6.39830119e+04
#  -6.97520661e+04 -7.57047750e+04 -8.18411387e+04 -8.81611570e+04
#  -9.46648301e+04 -1.01352158e+05 -1.08223140e+05 -1.15277778e+05
# ...

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')
